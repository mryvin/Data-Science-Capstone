# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
airbnb = pd.read_csv('Cleaned_Airbnb.csv')
airbnb = airbnb.drop('Unnamed: 0', axis=1)
airbnb
# Out:
#              id                                               name  host   id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# ...         ...                                                ...        ...
# 39113  36484665    Charming one bedroom - newly renovated rowhouse    8232441
# 39114  36485057      Affordable room in Bushwick/East Williamsburg    6570630
# 39115  36485431            Sunny Studio at Historical Neighborhood   23492952
# 39116  36485609               43rd St. Time Square-cozy single bed   30985759
# 39117  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
#          [host_name] neighbourhood group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 1           Jennifer           Manhattan             Midtown  40.75362
# 2          Elisabeth           Manhattan              Harlem  40.80902
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 4              Laura           Manhattan         East Harlem  40.79851
# ...              ...                 ...                 ...       ...
# 39113        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 39114        Marisol            Brooklyn            Bushwick  40.70184
# 39115  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 39116            Taz           Manhattan      Hell's Kitchen  40.75751
# 39117     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude    room and type  minimum nights  number of reviews (total)  \
# 0      -73.97237     Private room               1                          9
# 1      -73.98377  Entire home/apt               1                         45
# 2      -73.94190     Private room               3                          0
# 3      -73.95976  Entire home/apt               1                        270
# 4      -73.94399  Entire home/apt              10                          9
# ...          ...              ...             ...                        ...
# 39113  -73.94995     Private room               2                          0
# 39114  -73.93317     Private room               4                          0
# 39115  -73.94867  Entire home/apt              10                          0
# 39116  -73.99112      Shared room               1                          0
# 39117  -73.98933     Private room               7                          0
#
#       last review (date)  reviews per month  floor  noise.dB.  price
# 0             2018-10-19               0.21      1  69.056465    149
# 1             2019-05-21               0.38      1  56.054278    225
# 2                    NaN               0.00      1  56.054278    150
# 3             2019-07-05               4.64      1  69.056465     89
# 4             2018-11-19               0.10      1  56.054278     80
# ...                  ...                ...    ...        ...    ...
# 39113                NaN               0.00      1  69.056465     70
# 39114                NaN               0.00      1  69.056465     40
# 39115                NaN               0.00      1  56.054278    115
# 39116                NaN               0.00      1  56.054278     55
# 39117                NaN               0.00      1  56.054278     90
#
# [39118 rows x 16 columns]

# %%
fig, axs = plt.subplots(3, 3, figsize=(25, 25))

x = 0
y = 0

for i in airbnb:
    if i != 'price':
        continue
    for j in airbnb:
        if i == j:
            continue
        if airbnb[j].map(type).eq(str).any() or j == 'id' or j == 'host   id':
            continue
        #a, b = np.polyfit(airbnb[i], airbnb[j], 1)
        axs[x,y].scatter(airbnb[i],airbnb[j],s=1)
        #axs[x,y].plot(airbnb[i], a*airbnb[j]+b,color='deepskyblue')
        temp = " and "
        title = i + temp + j
        axs[x, y].set_title(title,fontsize=7)
        y += 1
        if y > 2:
            x +=1
            y = 0

# %%
fig, axs = plt.subplots(3, 3, figsize=(25, 25))

x = 0
y = 0

for i in airbnb:
    if i != 'noise.dB.':
        continue
    for j in airbnb:
        if i == j:
            continue
        if airbnb[j].map(type).eq(str).any() or j == 'id' or j == 'host   id':
            continue
        #a, b = np.polyfit(airbnb[i], airbnb[j], 1)
        axs[x,y].scatter(airbnb[i],airbnb[j],s=1)
        #axs[x,y].plot(airbnb[i], a*airbnb[j]+b,color='deepskyblue')
        temp = " and "
        title = i + temp + j
        axs[x, y].set_title(title,fontsize=7)
        y += 1
        if y > 2:
            x +=1
            y = 0

# %%
fig, axs = plt.subplots(3, 3, figsize=(25, 25))

x = 0
y = 0

for i in airbnb:
    if i != 'floor':
        continue
    for j in airbnb:
        if i == j:
            continue
        if airbnb[j].map(type).eq(str).any() or j == 'id' or j == 'host   id':
            continue
        #a, b = np.polyfit(airbnb[i], airbnb[j], 1)
        axs[x,y].scatter(airbnb[i],airbnb[j],s=1)
        #axs[x,y].plot(airbnb[i], a*airbnb[j]+b,color='deepskyblue')
        temp = " and "
        title = i + temp + j
        axs[x, y].set_title(title,fontsize=7)
        y += 1
        if y > 2:
            x +=1
            y = 0

# %%
brooklyn = airbnb.loc[airbnb['neighbourhood group'] == 'Brooklyn']
brooklyn
# Out:
#              id                                             name  host   id  \
# 0          2539               Clean & quiet apt home by the park       2787
# 3          3831                  Cozy Entire Floor of Brownstone       4869
# 6          5121                                  BlissArtsSpace!       7356
# 12         6848                 Only 2 stops to Manhattan studio      15991
# 13         7097                Perfect for Your Parents + Garden      17571
# ...         ...                                              ...        ...
# 39106  36482231                        Bushwick _ Myrtle-Wyckoff   66058896
# 39107  36482783      Brooklyn Oasis in the heart of Williamsburg  274307600
# 39110  36483152  Garden Jewel Apartment in Williamsburg New York  208514239
# 39113  36484665  Charming one bedroom - newly renovated rowhouse    8232441
# 39114  36485057    Affordable room in Bushwick/East Williamsburg    6570630
#
#          [host_name] neighbourhood group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 6              Garon            Brooklyn  Bedford-Stuyvesant  40.68688
# 12     Allen & Irina            Brooklyn        Williamsburg  40.70837
# 13              Jane            Brooklyn         Fort Greene  40.69169
# ...              ...                 ...                 ...       ...
# 39106          Luisa            Brooklyn            Bushwick  40.69652
# 39107       Jonathan            Brooklyn        Williamsburg  40.71790
# 39110          Melki            Brooklyn        Williamsburg  40.71232
# 39113        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 39114        Marisol            Brooklyn            Bushwick  40.70184
#
#        longitude    room and type  minimum nights  number of reviews (total)  \
# 0      -73.97237     Private room               1                          9
# 3      -73.95976  Entire home/apt               1                        270
# 6      -73.95596     Private room              45                         49
# 12     -73.95352  Entire home/apt               2                        148
# 13     -73.97185  Entire home/apt               2                        198
# ...          ...              ...             ...                        ...
# 39106  -73.91079     Private room              20                          0
# 39107  -73.96238     Private room               7                          0
# 39110  -73.94220  Entire home/apt               1                          0
# 39113  -73.94995     Private room               2                          0
# 39114  -73.93317     Private room               4                          0
#
#       last review (date)  reviews per month  floor  noise.dB.  price
# 0             2018-10-19               0.21      1  69.056465    149
# 3             2019-07-05               4.64      1  69.056465     89
# 6             2017-10-05               0.40      1  69.056465     60
# 12            2019-06-29               1.20      1  69.056465    140
# 13            2019-06-28               1.72      1  69.056465    215
# ...                  ...                ...    ...        ...    ...
# 39106                NaN               0.00      1  69.056465     40
# 39107                NaN               0.00      1  69.056465    190
# 39110                NaN               0.00      1  69.056465    170
# 39113                NaN               0.00      1  69.056465     70
# 39114                NaN               0.00      1  69.056465     40
#
# [16084 rows x 16 columns]

# %%
fig, axs = plt.subplots(3, 3, figsize=(25, 25))

x = 0
y = 0

for i in brooklyn:
    if i != 'price':
        continue
    for j in brooklyn:
        if i == j:
            continue
        if brooklyn[j].map(type).eq(str).any() or j == 'id' or j == 'host   id':
            continue
        #a, b = np.polyfit(brooklyn[i], brooklyn[j], 1)
        axs[x,y].scatter(brooklyn[i],brooklyn[j],s=1)
        #axs[x,y].plot(brooklyn[i], a*brooklyn[j]+b,color='deepskyblue')
        temp = " and "
        title = i + temp + j
        axs[x, y].set_title(title,fontsize=7)
        y += 1
        if y > 2:
            x +=1
            y = 0
